# %% [markdown]
# # **Industry: STOCK PREDICTION**
#
# ### **Topic:** Stock prediction using machine learning techniques
#
# ### Github repo: https://github.com/spranavi28/Stock-Market-Price-Prediction/
#
# ### Dataset: https://www.kaggle.com/datasets/vasilis73/ftse-100-index, https://www.kaggle.com/datasets/paultimothymooney/stock-market-data

# %% [markdown]
# Group - 1
# Vedant Bharatbhai Jasani
# Mahesh Kavuri
# Jahirabbas Joynal Khan
# Yashkumar Ashwinbhai Sanghani
# Pranavi Satheesan
# Surya Surya

# %% [markdown]
# # **Problem Statement:**
# The stock market is a central component of the global economy, yet its volatility often makes precise and reliable predictions a highly complex task (Context). Traditional forecasting techniques, such as linear regression and time-series analysis, may not suffice due to their inability to model and predict the intricate, non-linear relationships among the numerous variables that influence stock prices (Issue). These techniques also fail to account for the temporal dependencies in the stock market data and often make assumptions that do not hold true in this context (Relevance). In this study, we aim to explore the use of advanced machine learning algorithms to develop more sophisticated and effective prediction models for the stock market (Objective).
#
# #### **Breakdown of Problem Statement:**
#
# The stock market is a central component of the global economy, yet its volatility often makes precise and reliable predictions a highly complex task. Traditional forecasting techniques, such as linear regression and time-series analysis, may not suffice due to their inability to model and predict the intricate, non-linear relationships among the numerous variables that influence stock prices. For instance, stock prices are not only affected by the financial health of a company, but also macroeconomic indicators, political stability, investor sentiment, and unpredictable events like natural disasters or pandemics, among other factors.
#
# These traditional techniques also fail to account for the temporal dependencies in the stock market data, i.e., they do not consider how the past movement of a stock price might influence its future. This is particularly significant given the time-series nature of stock market data. Furthermore, these methods often make assumptions such as the normality of data or constant variance over time, which is not usually the case in the stock market.
#
# The limitations of traditional methods can lead to suboptimal predictive performance, resulting in miscalculated investment decisions, financial losses, and market instability. This problem, therefore, highlights a crucial need for more sophisticated and effective prediction models. The potential solution lies in leveraging advanced machine learning algorithms capable of modelling complex non-linear relationships and handling high-dimensional and time-series data.
#
#
# #### **Purpose, Vision & Scope:**
# The primary purpose of addressing this problem is to increase the accuracy and reliability of predicting stock closing prices. By achieving this, we aim to provide valuable assistance to various stakeholders, ranging from individual investors to financial institutions. Accurate stock market predictions can lead to improved investment decisions and risk management, thus reducing financial losses and increasing potential profits. Furthermore, it can contribute to stabilizing the stock market, as improved predictions can help prevent drastic market reactions based on poor forecasting.
#
# Our vision is to create a predictive model that surpasses traditional forecasting techniques by effectively harnessing the power of machine learning and deep learning. We strive to build a model that learns from historical data, captures complex non-linear relationships between variables, and considers temporal dependencies in stock price data, thereby delivering accurate and reliable predictions. The model should be robust, capable of adapting to new data, and scalable to incorporate more variables or features that could potentially impact stock prices.
#
# Ideally, the proposed solution could serve as a foundation for creating a comprehensive decision support system for investors. This system could incorporate not just price predictions, but also other aspects of investment decision-making, such as risk assessment, portfolio optimization, and market sentiment analysis.
#
# The scope of the problem and the proposed solution encompasses the entire stock market, with the possibility of application to specific sectors or individual stocks. While the initial focus could be on larger and more stable stocks (which typically have more available data), the ultimate goal is to develop a model that is flexible enough to be applied to any stock.
#
# The scope also includes both short-term and long-term predictions. While short-term predictions (daily or weekly) could be useful for active traders looking to buy and sell stocks frequently, long-term predictions (monthly, yearly, or beyond) could serve longer-term investors.
#
# It's important to note that while we aim to improve the accuracy of stock price predictions, no model can be 100% accurate due to the inherently unpredictable nature of stock markets. The unpredictability arises from numerous factors like sudden changes in investor sentiment, unanticipated geopolitical events, or unexpected company news. Therefore, the proposed solution should be viewed as a tool to aid decision-making rather than a definitive predictor of future stock prices.
#
# Finally, while the main users of the proposed solution would likely be investors and financial institutions, it also has potential benefits for policymakers and regulators. An improved understanding of stock price movements could help in designing policies to stabilize markets and prevent crises.
#
# # **RESEARCH**
# ### **Machine Learning Predictions and Outcomes:**
#
# 1. Vijh, M., Chandola, D., Tikkiwal, V. A., & Kumar, A. (2020). Stock Closing Price Prediction using Machine Learning Techniques. Procedia Computer Science, 167, 599–606. https://doi.org/10.1016/j.procs.2020.03.326
#
# The predictions presented in this research paper aligned exceptionally well with our expectations. The researchers employed two algorithms, namely Artificial Neural Networks (ANN) and Random Forest (RF), to predict the next day's closing price of the stock. The rationale behind utilizing these algorithms lies in their ability to handle the complex patterns formed by the multiple parameters that influence stock values.
#
# Upon conducting a comparative analysis using metrics such as Root Mean Square Error (RMSE), Mean Absolute Percentage Error (MAPE), and Mean Bias Error (MBE), the research paper unequivocally demonstrated that ANN outperformed RF in predicting stock prices. The results obtained from the ANN model showcased impressive values, with an RMSE of 0.42, MAPE of 0.77, and MBE of 0.013.
#
# The research paper, with its comprehensive analysis and compelling results, served as a wellspring of inspiration for formulating our hypothesis. Witnessing the superior predictive capabilities of the ANN algorithm, We became motivated to explore its potential further and hypothesized that by incorporating additional data sources such as financial news articles and vital financial parameters like closing price, traded volume, and profit and loss statements, even more accurate predictions could be achieved.
#
# The research paper's findings not only validated the challenges associated with stock market prediction but also hints toward the future scope of deep learning models. The prospect of integrating textual data from financial news articles with quantitative parameters appeared promising, hinting at the possibility of achieving unprecedented accuracy and unlocking hidden patterns in the stock market. Inspired by these notions, our hypothesis evolved and extended to encompass the potential development of advanced deep learning models for enhanced predictive capabilities in stock market forecasting.
#
# 2. Subasi, A., Amir, F., Bagedo, K., Shams, A., & Sarirete, A. (2021). Stock Market Prediction Using Machine Learning. Procedia Computer Science, 194, 173–179. https://doi.org/10.1016/j.procs.2021.10.071
#
# The research paper's predictions were in line with our expectations. The paper employed various machine learning algorithms to compare their performance in stock market prediction, including Random Forest, Bagging, AdaBoost, Decision Trees, ANN, K-NN, and SVM. The algorithms were evaluated using both normal datasets and leaked datasets.
#
# The results revealed that retraining with leaked data led to higher accuracy results across the classifiers. Random Forest with leaked data and Bagging with leaked data demonstrated the most satisfactory performance compared to other classifiers. Additionally, the study compared the performance of the algorithms on different stock indices datasets such as NASDAQ, NYSE, NIKKEI, and FTSE.
#
# The research paper's findings inspired us to form our hypothesis by emphasizing the significance of using leaked data for improved accuracy in stock market prediction. It highlighted the superior performance of Random Forest and Bagging algorithms with leaked data. This insight propelled us to explore and investigate the potential of these algorithms further, aiming to achieve similar satisfactory results in our own research.
#
# Overall, the research paper's conclusions validated my expectations regarding the importance of algorithm selection and the benefits of leveraging leaked data in stock market prediction. It served as a valuable source of inspiration for formulating our hypothesis and further guided our research direction.
#
# 3. Deshmukh, Y., Saratkar, D., & Tiwari, Y. (2019). Stock Market Prediction Using Machine Learning. Nternational Journal of Advanced Research in Computer and Communication Engineering. https://doi.org/10.17148/ijarcce.2019.8107
#
# The research paper's predictions aligned with our expectations. The paper utilized artificial neural networks (ANN) as the algorithm of choice for predicting the behavior and trends of stocks. ANN was selected due to its ability to effectively analyze and process diverse formats of data, even in the presence of imprecise and incomplete input data. The flexibility of neural networks in handling uncertain information and the potential for combining them with other methods made them a viable alternative to conventional techniques.
#
# The results of the research were deemed satisfactory as they successfully achieved the objective of predicting the closing price of stocks. The utilization of ANN demonstrated its feasibility as a tool for revealing market behavior and providing privileged information to investors. Additionally, the paper mentioned the potential benefits of combining ANN with other techniques for enhanced prediction accuracy.
#
# The research paper's exploration of neural networks and their ability to make accurate predictions, drawing parallels with weather forecasting, inspired our hypothesis formulation. The understanding that neural networks can effectively handle uncertain data and the mention of their potential combinations with other methods piqued our interest in further exploring the capabilities of neural networks in stock market prediction.
#
# Furthermore, the paper highlighted the limitations of neural networks, such as the need for a large amount of previous data, the lack of knowledge regarding the optimal network architecture, and the potential decrease in accuracy for complex networks. These limitations influenced our research approach by encouraging a critical evaluation of the application of neural networks, considering the statistical relevance of the results, and emphasizing the need for careful data design and analysis.
#
# Overall, the research paper's findings and insights regarding the use of ANN in stock market prediction provided valuable guidance and inspiration for our hypothesis development and research direction.
#
#
# # **Machine Learning Solution:**
#
# Our approach incorporates the use of Deep Neural Networks (DNN) in addition to Artificial Neural Networks (ANN) for stock market prediction. Inspired by the potential of deep learning models mentioned in the first research paper by Vijh et al. (2020), we recognize the value of DNN in capturing intricate patterns and relationships in financial market data.
#
# By leveraging the depth and complexity of DNN architectures, we aim to enhance the predictive capabilities of our models. The ability of DNNs to learn hierarchical representations of data and extract high-level features can potentially reveal hidden patterns and trends in stock market behavior. This, in turn, can provide investors with valuable insights and enable the development of more effective trading strategies.
#
# In conjunction with the utilization of ANN, we propose incorporating DNNs into our research methodology. By combining the strengths of both ANN and DNN, we anticipate achieving superior prediction accuracy and a deeper understanding of the underlying dynamics of stock prices.
#
# Therefore, our approach involves using both ANN and DNN to develop predictive models for stock market forecasting. We are inspired by the potential of DNN to handle complex data patterns and extract meaningful features, which aligns with our goal of achieving accurate and robust predictions in the stock market domain.
#
# # ** Citations and Links: **
# 1. Vijh, M., Chandola, D., Tikkiwal, V. A., & Kumar, A. (2020). Stock Closing Price Prediction using Machine Learning Techniques. Procedia Computer Science, 167, 599–606. https://doi.org/10.1016/j.procs.2020.03.326
#
# 2. Subasi, A., Amir, F., Bagedo, K., Shams, A., & Sarirete, A. (2021). Stock Market Prediction Using Machine Learning. Procedia Computer Science, 194, 173–179. https://doi.org/10.1016/j.procs.2021.10.071
#
# 3. Deshmukh, Y., Saratkar, D., & Tiwari, Y. (2019). Stock Market Prediction Using Machine Learning. Nternational Journal of Advanced Research in Computer and Communication Engineering. https://doi.org/10.17148/ijarcce.2019.8107

# %% [markdown]
# ## Background Information
# | Reference |Explanation |  Dataset/Input |Weakness
# | --- | --- | --- | --- |
# | Vijh, M. [1] |  The research paper, with its comprehensive analysis and compelling results, served as a wellspring of inspiration for formulating our hypothesis.| FTSE STOCK dataset  | They didnt implement using various models
# | Subasi, A. [2] | Used Random Forest, Bagging, AdaBoost, Decision Trees, ANN, K-NN, and SVM. The algorithms were evaluated using both normal datasets and leaked datasets. |  Nasdaq, FTSE, NSE | The accuracies for few mmodels are less
# | Deshmukh, Y. [2] | The paper utilized artificial neural networks (ANN) as the algorithm of choice for predicting the behavior and trends of stocks | Nasdaq | The accuracies can be improved by hyper tuning techniques

# %% [markdown]
# Basic coding part which includes data cleaning, pre-processing techniques and ML technique

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
df = pd.read_csv("D:/AI/SEM 2/Emerging AI Technologies/Assignment 1/Datasets/NASDAQ.csv")

# %%
df
# Out:
#             Date        Low       Open    Volume       High      Close  \
# 0     27-09-2005  19.100000  21.049999    961200  21.400000  19.299999
# 1     28-09-2005  19.200001  19.299999   5747900  20.530001  20.500000
# 2     29-09-2005  20.100000  20.400000   1078200  20.580000  20.209999
# 3     30-09-2005  20.180000  20.260000   3123300  21.049999  21.010000
# 4     03-10-2005  20.900000  20.900000   1057900  21.750000  21.500000
# ...          ...        ...        ...       ...        ...        ...
# 4328  06-12-2022  14.000000  14.140000  20781500  14.340000  14.330000
# 4329  07-12-2022  13.530000  14.240000  28161400  14.240000  13.550000
# 4330  08-12-2022  13.380000  13.650000  25300900  13.800000  13.600000
# 4331  09-12-2022  13.420000  13.520000  18489800  13.660000  13.530000
# 4332  12-12-2022  13.450000  13.490000   8048550  13.930000  13.915000
#
#       Adjusted Close
# 0          18.194910
# 1          19.326204
# 2          19.052805
# 3          19.807001
# ...

# %%
import matplotlib.pyplot as plt

# Convert the 'Date' column to datetime objects
df['Date'] = pd.to_datetime(df['Date'])

# Plot the 'Open' column over time
plt.plot(df['Date'], df['Open'])
plt.xlabel('Date')
plt.ylabel('Open')

plt.title('Stock Price Over Time')
plt.show()
# Out:
# C:\Users\91913\AppData\Local\Temp\ipykernel_29840\660636229.py:4: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
import seaborn as sns

# Convert the 'Date' column to datetime objects
df['Date'] = pd.to_datetime(df['Date'])

# Create a pairplot
sns.pairplot(df)
plt.show()

# %%
# Convert the 'Date' column to datetime objects
df['Date'] = pd.to_datetime(df['Date'])

# Extract the year, month, and day as separate columns
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day

# Drop the original 'Date' column
df = df.drop(columns=['Date'])


# Scale the data
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(df)

# Split the data into training and testing sets
train_size = int(len(df_scaled) * 0.8)
test_size = len(df_scaled) - train_size
train, test = df_scaled[0:train_size,:], df_scaled[train_size:len(df_scaled),:]

# Convert the data into a 3D array (a sequence with t timesteps and d dimensions)
def create_sequences(data, t, d):
    X, y = [], []
    for i in range(len(data)-t-1):
        a = data[i:(i+t), :]
        X.append(a)
        y.append(data[i + t, :])
    return np.array(X), np.array(y)

# Create sequences of t timesteps with d dimensions
t = 10 # timesteps
d = 9 # dimensions (including year, month, and day)
X_train, y_train = create_sequences(train, t, d)
X_test, y_test = create_sequences(test, t, d)

# %%
# Build the model
model = Sequential()
model.add(LSTM(50, input_shape=(t, d)))
model.add(Dense(d))
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
history = model.fit(X_train,
                    y_train,
                    epochs=50,
                    batch_size=1,
                    verbose=1
                   )
# Out:
# Epoch 1/50
# 3455/3455 [==============================] - 10s 3ms/step - loss: 0.0102
# Epoch 2/50
# 3455/3455 [==============================] - 12s 3ms/step - loss: 0.0060
# Epoch 3/50
# 3455/3455 [==============================] - 12s 4ms/step - loss: 0.0054
# Epoch 4/50
# 3455/3455 [==============================] - 11s 3ms/step - loss: 0.0052
# Epoch 5/50
# 3455/3455 [==============================] - 12s 4ms/step - loss: 0.0048
# Epoch 6/50
# 3455/3455 [==============================] - 14s 4ms/step - loss: 0.0047
# Epoch 7/50
# 3455/3455 [==============================] - 11s 3ms/step - loss: 0.0046
# Epoch 8/50
# 3455/3455 [==============================] - 13s 4ms/step - loss: 0.0044
# Epoch 9/50
# 3455/3455 [==============================] - 22s 6ms/step - loss: 0.0043
# Epoch 10/50
# 3455/3455 [==============================] - 22s 6ms/step - loss: 0.0043
# Epoch 11/50
# 3455/3455 [==============================] - 23s 7ms/step - loss: 0.0041
# Epoch 12/50
# ...

# %%
import matplotlib.pyplot as plt

# Plot loss on the same graph

plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('Accuracy/Loss')
plt.xlabel('Epoch')
plt.legend(['Loss'], loc='upper left')
plt.show()

# %%
# Test the model
test_error = model.evaluate(X_test, y_test, verbose=2)
print(f'Test error: {test_error}')
print(f'Accuracy: {(1-test_error) * 100}%')
# Out:
# 27/27 - 0s - loss: 0.0041 - 389ms/epoch - 14ms/step
# Test error: 0.004123006947338581
# Accuracy: 99.58769930526614%
